# %%
import numpy as np
import pandas as pd
import librosa
import IPython.display as ipd
import matplotlib.pyplot as plt
import audioread
#from google.colab import drive
import os

# Mount Google Drive to access audio files
#drive.mount('/content/drive')

# %%
# Set the folder path to your local directory with audio files
folder_path = "C:\\Users\\Dev\\Documents\\SpotifAI Audio Files Dataset"

# Loop through audio files in the specified folder
for audio_file in os.listdir(folder_path):
    if audio_file.endswith('.mp3'):
        audio_path = os.path.join(folder_path, audio_file)
        
        try:
            # Load the audio file using librosa, which will try audioread if needed
            x, sr = librosa.load(audio_path)
            print(f"Loaded {audio_file}")
        except Exception as e:
            print(f"Error loading {audio_file}: {e}")

# %%
# Set the folder path for audio files
folder_path = "C:\\Users\\Dev\\Documents\\SpotifAI Audio Files Dataset"

# Create an empty list to store DataFrames
all_chroma_dfs = []

# Loop through audio files in the specified folder
for audio_file in os.listdir(folder_path):
    if audio_file.endswith('.mp3'):
        audio_path = os.path.join(folder_path, audio_file)

        try:
            # Load the audio file
            x, sr = librosa.load(audio_path)

            # Calculate chroma features
            chroma = librosa.feature.chroma_stft(y=x, sr=sr)

            # Calculate mean and standard deviation of chroma
            chroma_mean = np.mean(chroma, axis=1)
            chroma_std = np.std(chroma, axis=1)

            # Generate the chroma DataFrame
            chroma_df = pd.DataFrame()
            for i in range(0, 12):
                chroma_df['chroma_mean_' + str(i)] = chroma_mean[i]
            for i in range(0, 12):
                chroma_df['chroma_std_' + str(i)] = chroma_std[i]
            chroma_df.loc[0] = np.concatenate((chroma_mean, chroma_std), axis=0)

            # Add a column for the audio file name
            chroma_df['Audio File'] = audio_file

            # Append the DataFrame to the list
            all_chroma_dfs.append(chroma_df)

        except Exception as e:
            print(f"Error loading {audio_file}: {e}")

# Concatenate all DataFrames into a single DataFrame
final_chroma_df = pd.concat(all_chroma_dfs, ignore_index=True)

# Display the final DataFrame
print(final_chroma_df)

# %%
import os
import numpy as np
import pandas as pd
import librosa

# Set the folder path to your local directory with audio files
folder_path = "C:\\Users\\Dev\\Documents\\SpotifAI Audio Files Dataset"

# Define the folder where you want to save the final CSV file on your computer
output_folder = "C:\\Users\\Dev\\Documents\\SpotifAI_MFCC_Data"
os.makedirs(output_folder, exist_ok=True)

# Initialize an empty DataFrame to store all MFCC data
all_mfccs_df = pd.DataFrame()

# Loop through audio files in the specified folder
for audio_file in os.listdir(folder_path):
    if audio_file.endswith('.mp3'):
        audio_path = os.path.join(folder_path, audio_file)
        
        try:
            # Load the audio file using librosa
            x, sr = librosa.load(audio_path)
            print(f"Loaded {audio_file}")

            # Calculate MFCCs
            mfccs = librosa.feature.mfcc(y=x, sr=sr, n_mfcc=13)
            mfccs_mean = np.mean(mfccs, axis=1)
            mfccs_std = np.std(mfccs, axis=1)

            # Create a dictionary for the current file's MFCC data
            mfcc_data = {'File': audio_file}
            for i in range(13):
                mfcc_data[f'mfccs_mean_{i}'] = mfccs_mean[i]
                mfcc_data[f'mfccs_std_{i}'] = mfccs_std[i]

            # Convert the dictionary to a DataFrame and concatenate it to the main DataFrame
            mfcc_df = pd.DataFrame([mfcc_data])
            all_mfccs_df = pd.concat([all_mfccs_df, mfcc_df], ignore_index=True)

        except Exception as e:
            print(f"Error loading {audio_file}: {e}")

# Save the combined DataFrame to a CSV file in the specified output folder
output_file_path = os.path.join(output_folder, "combined_mfcc_data.csv")
all_mfccs_df.to_csv(output_file_path, index=False)
print(f"All MFCC data saved to {output_file_path}")
# Out:
# Loaded (I Can't Get No) Satisfaction - Mono Version.mp3
# Loaded 1, 2 Step (Supersonic).mp3
# Loaded 1-800-hot-n-fun - LE SSERAFIM.mp3
# Loaded 1900's.mp3
# Loaded 1979 - Remastered 2012.mp3
# Loaded 2 Things.mp3
# Loaded 360 - Charlie xcx.mp3
# Loaded 3D (feat. Jack Harlow) - Jung Kook, Jack Harlow.mp3
# Loaded 44 (Forget Forever) - WOOSUNG.mp3
# Loaded 7HEAVEN - PURPLE KISS.mp3
# Loaded A Red Flag.mp3
# Loaded All Along the Watchtower.mp3
# Loaded All I Ever Asked.mp3
# Loaded All Nighter.mp3
# Loaded All Right Now.mp3
# Loaded Allergy - (G)I-DLE.mp3
# Loaded alone with you.mp3
# Loaded alright - raph.mp3
# Loaded Ambrosia.mp3
# Loaded American Boy.mp3
# Loaded American Woman - 7_ Single Version.mp3
# Loaded Amsterdam - Imagine Dragons.mp3
# Loaded Aphrodite.mp3
# Loaded Are You Gonna Go My Way.mp3
# Loaded Atmosphere.mp3
# Loaded Automatic - VANNER.mp3
# Loaded autumn.mp3
# Loaded Baby again...mp3
# Loaded Baby Powder.mp3
# Loaded Back for More (TXT Ver.) -TOMORROW X TOGETHER.mp3
# Loaded Bad Alive - English Version - WayV.mp3
# Loaded Bad Moon Rising.mp3
# Loaded Barracuda.mp3
# Loaded BBB - PURPLE KISS.mp3
# Loaded Be The One.mp3
# Loaded Beat Freak (ft. lau.ra).mp3
# Loaded Beggin'.mp3
# Loaded Best of You.mp3
# Loaded Better [from _Fantasy.1_].mp3
# Loaded Billie (loving arms).mp3
# Loaded Bitter Sweet Symphony - Remastered 2016.mp3
# Loaded Bittersweet Goodbye - Tiësto’s Hardcore Remix.mp3
# Loaded Black Dog - Remaster.mp3
# Loaded Black Eye - VERNON.mp3
# Loaded Black Hole Sun.mp3
# Loaded Black Magic Woman - Single Version.mp3
# Loaded blah blah blah - Reiley.mp3
# Loaded Blame (feat. John Newman).mp3
# Loaded bleach - JUNO.mp3
# Loaded Bonnie & Clyde - YUQI.mp3
# Loaded Boulevard of Broken Dreams.mp3
# Loaded Boyfriend - Dove Cameron .mp3
# Loaded Boyfriend - YEONJUN.mp3
# Loaded Breakfast - Dove Cameron.mp3
# Loaded Bring it on (English ver.) - ONEUS.mp3
# Loaded Broken Melodies - NCT DREAM, JVKE.mp3
# Loaded Broken Record.mp3
# Loaded Brought The Heat Back - ENHYPEN.mp3
# Loaded Brown Sugar.mp3
# Loaded Bubblegum Bitch - MARINA.mp3
# Loaded Butterfly.mp3
# Loaded Buyer's Remorse (feat. Omar Apollo).mp3
# Loaded California Dreamin' (feat. High Jinx).mp3
# Loaded Calling (Lose My Mind) - Radio Edit.mp3
# Loaded Candy Rain.mp3
# Loaded Can’t Fight The Feeling.mp3
# Loaded Carry on Wayward Son.mp3
# Loaded Cat & Dog - TOMORROW X TOGETHER.mp3
# Loaded catching feelings.mp3
# Loaded Charlie, Last Name Wilson.mp3
# Loaded Chasing That Feeling (English Ver. – Digital Only) - TOMORROW X TOGETHER.mp3
# Loaded Check Out.mp3
# Loaded Chemicals (feat. Thomas Troelsen).mp3
# Loaded Cigarette (Feat. Tablo, MISO).mp3
# Loaded close with desires (feat. thuy).mp3
# Loaded cloud 11 - thuy.mp3
# Loaded Come & Talk To Me.mp3
# Loaded Come My Way.mp3
# Loaded Come Together - Remastered 2009.mp3
# Loaded cough drops - almost monday.mp3
# Loaded CPR.mp3
# Loaded crash & burn.mp3
# Loaded Crazy Train.mp3
# Loaded Crush - Seventeen.mp3
# Loaded curious_furious - WILLOW.mp3
# Loaded Cutting Shapes.mp3
# Loaded Damage.mp3
# Loaded Dance No More (with Kaleena Zanders).mp3
# Loaded Danza Kuduro - Tiësto Remix.mp3
# Loaded Darl+ing - SEVENTEEN.mp3
# Loaded darling, he lied.mp3
# Loaded Day by Day - A COLORS SHOW.mp3
# Loaded Day That I Died - WOOSUNG.mp3
# Loaded Daylight.mp3
# Loaded DEAD MAN WALKING.mp3
# Loaded Deep.mp3
# Loaded Delilah (pull me out of this).mp3
# Loaded demons.mp3
# Loaded Detroit Rock City.mp3
# Loaded Devil by the Window - TOMORROW X TOGETHER.mp3
# Loaded dirty dancer.mp3
# Loaded Disillusioned (with serpentwithfeet).mp3
# Loaded Distance - Volac Remix.mp3
# Loaded Do It Like That - TOMORROW X TOGETHER.mp3
# Loaded Do It To It - Tiësto Remix.mp3
# Loaded Don't Cry (Original).mp3
# Loaded Don't Stop.mp3
# Loaded Dopamine.mp3
# Loaded Drifting.mp3
# Loaded Drugs From Amsterdam.mp3
# Loaded Earth, Wind & Fire (English Ver.) - BOYNEXTDOOR.mp3
# Loaded EASY (English ver.) - LESSERAFIM.mp3
# Loaded Easy.mp3
# Loaded Eat Your Man (with Nelly Furtado).mp3
# Loaded Edge of Seventeen - 2016 Remaster.mp3
# Loaded Edge of Seventeen.mp3
# Loaded Electricity.mp3
# Loaded Escape - John Summit Remix.mp3
# Loaded Eve, Psyche & the Bluebeard’s wife (English Ver.) - LE SERRAFIM.mp3
# Loaded Even Flow.mp3
# Loaded Everlong.mp3
# Loaded Every Day.mp3
# Loaded Every Step.mp3
# Loaded Everything You Have Done.mp3
# Loaded Fall In Love Again - P1Harmony.mp3
# Loaded Fallin’ (Adrenaline) - AB6IX Remix - Why Don't We, AB6IX.mp3
# Loaded Farewell, Neverland - TOMORROW X TOGETHER.mp3
# Loaded Feel the POP - ZEROBASEONE.mp3
# Loaded Feelin' Like - PENTAGON.mp3
# Loaded FEELINGS ON SILENT (feat. Wale).mp3
# Loaded Figure You Out - VIOLA.mp3
# Loaded Fine Day Anthem.mp3
# Loaded Fire in the belly - LE SERAFIM.mp3
# Loaded Flowering - SOOJIN.mp3
# Loaded Fly Away.mp3
# Loaded Fly Kicks - Wax Motif Remix.mp3
# Loaded Fond Adieu.mp3
# Loaded For What It's Worth.mp3
# Loaded Forget It.mp3
# Loaded FREAK - YUQI.mp3
# Loaded Free (with Ellie Goulding) - Joel Corry Remix.mp3
# Loaded Free (with Ellie Goulding).mp3
# Loaded Freudian.mp3
# Loaded Gecko (Overdrive) - Radio Edit.mp3
# Loaded Get A Guitar (English Version) - RIIZE.mp3
# Loaded Get Away.mp3
# Loaded Get You (feat. Kali Uchis).mp3
# Loaded Ghost Town - New Rules.mp3
# Loaded Gimme Shelter.mp3
# Loaded Gimme Some Keys.mp3
# Loaded Gimme That Bounce.mp3
# Loaded Give It To Me - Full Vocal Mix.mp3
# Loaded Good Care.mp3
# Loaded Goodies.mp3
# Loaded Happily Ever After - TOMORROW X TOGETHER.mp3
# Loaded Happy Fools (feat. Coi Leray) - TOMORROW X TOGETHER.mp3
# Loaded HARD KNOCK LULLABY.mp3
# Loaded Head & Heart (feat. MNEK) - Tiësto Remix.mp3
# Loaded HEAD OVER HEELS - Gun Boi Kaz.mp3
# Loaded Heal Me - Biscits Remix.mp3
# Loaded Heartbreak Anniversary.mp3
# Loaded Her Way.mp3
# Loaded Human (feat. Echoes).mp3
# Loaded I Hate Myself for Loving You.mp3
# Loaded I Was Made For Lovin' You (feat. Nile Rodgers & House Gospel Choir).mp3
# Loaded IC+B.mp3
# Loaded Idontwannaknowyou! - MICO.mp3
# Loaded If I Ain't Got You.mp3
# Loaded If I Never See You Again.mp3
# Loaded If You Let Me.mp3
# Loaded ificouldbelikeu.mp3
# Loaded ifuleave (feat. Mary J. Blige).mp3
# Loaded Immigrant Song - Remaster.mp3
# Loaded Impossible - RIIZE.mp3
# Loaded In The Air Tonight - 2015 Remastered.mp3
# Loaded IN THE AIR.mp3
# Loaded In the Night.mp3
# Loaded In The Yuma (feat. Aatig).mp3
# Loaded in2minds.mp3
# Loaded It's Alright - P1Harmony.mp3
# Loaded IT'S NOT THAT SERIOUS.mp3
# Loaded Ivy.mp3
# Loaded Japanese Denim.mp3
# Loaded Jungle.mp3
# Loaded jupiter - almost monday.mp3
# Loaded Just Friends (Sunny).mp3
# Loaded Kickstart My Heart.mp3
# Loaded Kill Bill.mp3
# Loaded Killin' Me Good (English Ver.) - JIHYO.mp3
# Loaded La Danza.mp3
# Loaded Last Nite.mp3
# Loaded Learn to Fly.mp3
# Loaded Left and Right (Feat. Jung Kook of BTS) - Charlie Puth, Jung Kook, BTS.mp3
# Loaded Let Me Go.mp3
# Loaded Let Me Love You.mp3
# Loaded Lets Try It.mp3
# Loaded Light.mp3
# Loaded Like I Want You.mp3
# Loaded Listen.mp3
# Loaded Livin' On A Prayer.mp3
# Loaded LOML.mp3
# Loaded LOOK SO PRETTY - Gun Boi Kaz.mp3
# Loaded Lose Control.mp3
# Loaded Losing Control.mp3
# Loaded Lost.mp3
# Loaded Love Affair.mp3
# Loaded Lovers In A Past Life (with Rag'n'Bone Man) - LP Giobbi Remix.mp3
# Loaded LUNCH - Billie Eilish .mp3
# Loaded Lying To You.mp3
# Loaded MADE UP YOUR MIND - Gun Boi Kaz.mp3
# Loaded Magic - TOMORROW X TOGETHER.mp3
# Loaded Make It Happen - Dom Dolla Remix.mp3
# Loaded Make Me Feel.mp3
# Loaded Mary Jane (All Night Long).mp3
# Loaded Mary Jane's Last Dance.mp3
# Loaded Master of Puppets (Remastered).mp3
# Loaded Me).mp3
# Loaded Meet Me in Amsterdam.mp3
# Loaded Memories.mp3
# Loaded Message In A Bottle.mp3
# Loaded Million Voices - Radio Edit.mp3
# Loaded Miracle (with Ellie Goulding) - Mau P Remix.mp3
# Loaded Miracle Maker.mp3
# Loaded Mirage.mp3
# Loaded MISS HOLLYWOOD - Gun Boi Kaz.mp3
# Loaded Monkey Wrench.mp3
# Loaded Moonlight - AB6IX, Reiley .mp3
# Loaded MOONLIGHT SUNRISE - TWICE.mp3
# Loaded Moonlight.mp3
# Loaded Moonlit Floor - LISA.mp3
# Loaded More Baby.mp3
# Loaded More Than a Feeling.mp3
# Loaded Mr. Blue Sky.mp3
# Loaded Mr. Brightside.mp3
# Loaded My Boo.mp3
# Loaded My City (feat. Katy Tiz).mp3
# Loaded My Humps.mp3
# Loaded My Luv (feat. Bibi Bourelly).mp3
# Loaded Never Tell.mp3
# Loaded New Gold (feat. Tame Impala and Bootie Brown) - Dom Dolla Remix.mp3
# Loaded next door (feat. ASTN).mp3
# Loaded Nice & Slow - Ryan James Carr Remake.mp3
# Loaded Nice Guy (English Ver.) - BOYNEXTDOOR.mp3
# Loaded No One Knows.mp3
# Loaded No One.mp3
# Loaded Notorious.mp3
# Loaded Novacane.mp3
# Loaded Number 1.mp3
# Loaded obsessed.mp3
# Loaded Oh my god - English Version - (G)-IDLE.mp3
# Loaded On & On.mp3
# Loaded On My Mind - Radio Edit.mp3
# Loaded On My Mind.mp3
# Loaded On My Youth - English Version - WayV.mp3
# Loaded Once Again.mp3
# Loaded Once in a Lifetime - 2005 Remaster.mp3
# Loaded One Way Or Another - Remastered 2001.mp3
# Loaded options - kupiter.mp3
# Loaded Over 85.mp3
# Loaded P.Y.T. (Pretty Young Thing).mp3
# Loaded Paper Cuts (feat. New Vaticans) - WOOSUNG.mp3
# Loaded Parachute - YDE.mp3
# Loaded Paragraphs.mp3
# Loaded Pegasus.mp3
# Loaded Perfect Night - LESSERAFIM.mp3
# Loaded Phase Me - WOOSUNG.mp3
# Loaded Pick Me Up.mp3
# Loaded Pineapple Cognac.mp3
# Loaded Pink + White.mp3
# Loaded Please Do Not Lean (feat. BADBADNOTGOOD) - Bonus.mp3
# Loaded Poison.mp3
# Loaded Psycho Killer - 2005 Remaster.mp3
# Loaded Pull Up.mp3
# Loaded Pump It Louder.mp3
# Loaded Quarter Life - TOMORROW X TOGETHER.mp3
# Loaded Radio Edit.mp3
# Loaded Ray Of Solar.mp3
# Loaded Remember (feat. Stevie Appleton).mp3
# Loaded reminders.mp3
# Loaded Riders on the Storm.mp3
# Loaded Rock You Like A Hurricane.mp3
# Loaded Rocket Man (I Think It's Going To Be A Long, Long Time).mp3
# Loaded Rumble.mp3
# Loaded Run Free (Countdown).mp3
# Loaded RUSH.mp3
# Loaded SAD SONG (English Ver.) - P1harmony.mp3
# Loaded San Frandisco.mp3
# Loaded Saving Up.mp3
# Loaded Say My Name.mp3
# Loaded Schönefeld.mp3
# Loaded SECRETS - Chri$tian Gate$.mp3
# Loaded See In Color.mp3
# Loaded Self Control.mp3
# Loaded SET ME FREE (ENG) - TWICE.mp3
# Loaded Seven (feat. Latto) - Jung Kook, Latto.mp3
# Loaded Sexy In The Air - TAEMIN.mp3
# Loaded Sharp Dressed Man (2008 Remaster).mp3
# Loaded Should I Stay or Should I Go - Remastered.mp3
# Loaded Side Effects (feat. SATICA) - WOOSUNG, SATICA.mp3
# Loaded Skinny Loser - Sub Urban.mp3
# Loaded Sleep Now In the Fire.mp3
# Loaded Slither.mp3
# Loaded Slow Down.mp3
# Loaded Slow Ride - Edit.mp3
# Loaded Smells Like Teen Spirit.mp3
# Loaded Snooze.mp3
# Loaded Song 2 - 2012 Remaster.mp3
# Loaded SOS (Sex on Sight) (feat. USHER).mp3
# Loaded Spectrum (Say My Name) - Calvin Harris Remix.mp3
# Loaded Spell - Seventeen.mp3
# Loaded spotifydown.com - Better [from _Fantasy.1_].mp3
# Loaded Static.mp3
# Loaded stay (with Lydia Ganada) - yuni, Lydia Ganada.mp3
# Loaded summer.mp3
# Loaded Summertime - Live.mp3
# Loaded Summertime 2016.mp3
# Loaded Sun Is Dark.mp3
# Loaded Superpowers.mp3
# Loaded SWEAT - ZEROBASEONE.mp3
# Loaded Sweet Disposition - John Summit & Silver Panda Remix.mp3
# Loaded Sweet Home Alabama.mp3
# Loaded Sweet Juice - PURPLE KISS.mp3
# Loaded Sweet Nothing (feat. Florence Welch).mp3
# Loaded Sweet Venom (English Ver.) - ENHYPEN.mp3
# Loaded Symphony (feat. Zara Larsson) - Clean Bandit, Zara Larsson.mp3
# Loaded T4ke - PURPLE KISS.mp3
# Loaded Take Me Away.mp3
# Loaded Talk talk featuring troye sivan - Charlie xcx, Troye Sivan.mp3
# Loaded Taste - Sabrina Carpenter.mp3
# Loaded TECHNO + TEQUILA (feat. Morgan Harvill).mp3
# Loaded Tell Me Why - MEDUZA Remix.mp3
# Loaded Tell Me Why.mp3
# Loaded Temptation (feat. Poppy Baskcomb).mp3
# Loaded Tender Love.mp3
# Loaded That's You.mp3
# Loaded THATS MY BABY.mp3
# Loaded The Boys Are Back In Town.mp3
# Loaded The Calling.mp3
# Loaded The Man Who Sold The World - Live.mp3
# Loaded The Middle - Zedd, Maren Morris, Grey.mp3
# Loaded The Music Began To Play.mp3
# Loaded The Only Way Is Up - Radio Edit.mp3
# Loaded The Parade.mp3
# Loaded The Pretender.mp3
# Loaded These Four Walls.mp3
# Loaded Thinkin Bout You.mp3
# Loaded this is what forever feels like (with Nick Jonas) - JVKE, Nick Jonas.mp3
# Loaded Too Good.mp3
# Loaded Toroka.mp3
# Loaded Touch Me - PAX & Rui Da Silva Version.mp3
# Loaded Traingazing.mp3
# Loaded Tripping Over Air - Aidan Bissett.mp3
# Loaded Turn Me On (feat. Vula).mp3
# Loaded Turn off the Lights - Cages Remix.mp3
# Loaded Turn off the Lights.mp3
# Loaded Turn On The Lights again.. (feat. Future & Fred again..) - Anyma Remix.mp3
# Loaded Twisted.mp3
# Loaded Under Pressure - Remastered 2011.mp3
# Loaded Under the Bridge.mp3
# Loaded universe.mp3
# Loaded Uprising.mp3
# Loaded Upside Down.mp3
# Loaded VHS RAVE.mp3
# Loaded Violet.mp3
# Loaded VIRUS - Odd Mob Remix.mp3
# Loaded Voodoo.mp3
# Loaded Waiting.mp3
# Loaded Walk.mp3
# Loaded Want U Around (feat. Ruel).mp3
# Loaded Watermelon Sugar - Harry Styles.mp3
# Loaded We Could Be Love.mp3
# Loaded We Might Even Be Falling In Love (Duet).mp3
# Loaded Welcome To The People.mp3
# Loaded WET.mp3
# Loaded What A Life (feat. Stevie Appleton).mp3
# Loaded What This Could Be - Joe Jonas.mp3
# Loaded What You've Done To Me (feat. Bemendé).mp3
# Loaded Whatever (with Ava Max) - Tiësto Remix.mp3
# Loaded Where You Are.mp3
# Loaded Where You Want.mp3
# Loaded wherever u r (ft. V of BTS).mp3
# Loaded White Ferrari.mp3
# Loaded Whole Lotta Drugs.mp3
# Loaded Whole Lotta Love - 1990 Remaster.mp3
# Loaded Why Don't We.mp3
# Loaded Won't Get Fooled Again - Original Album Version.mp3
# Loaded Working For It.mp3
# Loaded World, Hold On - FISHER Rework.mp3
# Loaded XO (Only If You Say Yes) (English Ver.) - ENHYPEN, JVKE.mp3
# Loaded Yeah The Girls.mp3
# Loaded You Don't Know My Name.mp3
# Loaded You Give Me A Feeling.mp3
# Loaded You Know You Like It - Tchami Remix.mp3
# Loaded You Make Me Wanna....mp3
# Loaded You Really Got Me - 2015 Remaster.mp3
# Loaded You've Done Enough.mp3
# Loaded You.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] 1942 (feat. Yo Gotti & YBN Nahmir).mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] 21 Guns.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] 500lbs.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Alive.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] All My Life.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Alone + Easy Target.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] American Idiot.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Animal I Have Become.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] AP - Music from the film Boogie.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] ATM.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Bent.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] BHZ.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Big Dawgs.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Blueberry Faygo.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] BOP.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Breaking the Habit.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Breed.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Bullet With Butterfly Wings - Remastered 2012.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] BURN.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] BUTTERFLY EFFECT.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] By the Way.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Californication.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Can't Stop.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Change.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Come Out and Play.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Corte Madera, CA.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Crown Of Thorns.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Crunk Ain't Dead.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Dani California.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Dark Knight Dummo (feat. Travis Scott).mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Dead or Alive.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Don't Sweat The Technique.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Down Below.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] DUCKWORTH..mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Envy Me.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] F.N.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Fashion Killa.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Flocky Flocky (feat. Travis Scott).mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] FRANCE FREESTYLE.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Fuck A Feature.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] fukumean.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Futsal Shuffle 2020 - Bonus Track.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Gaspar Yanga.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Geekin’.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Gist.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Give It Away.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Go Down (feat. TisaKorean).mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] GOD'S COUNTRY.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Good Riddance (Time of Your Life).mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] guidance.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] gun smoke.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Heart-Shaped Box.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Hoodie (feat. BSlime & Lil Gotit).mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] HOP OUT THE VAN.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] HVN ON EARTH (with Kodak Black).mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] I Hate Everything About You.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] I Write Sins Not Tragedies.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] I.Crawl.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] IDGAF (feat. Yeat).mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Interstate Love Song - 2019 Remaster.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] IRATE (Freestyle).mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Jesus of Suburbia.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Johnny Dang (with Paul Wall & DRODi).mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Kamikaze.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Killing In The Name.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Kryptonite.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Lemon (feat. Drake) - Drake Remix.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Let It Die.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] letstalkaboutit.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Life Goes On.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Lifestyle (with Bas feat. A$AP Ferg).mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Light It Up.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Like a Stone.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Lord Pretty Flacko Jodye 2 (LPFJ2).mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] LOT OF ME.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Lovin On Me.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Loyal (feat. Lil Wayne & Tyga).mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Malibu (feat. Polo G).mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Mama's Glizzy.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Mannequin Challenge (feat. Juice WRLD).mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] MIDDLE CHILD.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Millions.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Mo Bamba.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Money In The Grave (Drake ft. Rick Ross).mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] MY EYES.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] My Hero.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Nakamura.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Nephew (feat. Lil Pump).mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] No Pole.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] No Son Of Mine.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Not Like Us.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Opps On Fire.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Out Of Love (feat. Internet Money).mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] OUT WEST (feat. Young Thug).mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Over.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] p angels.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Party Girl.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Plug Walk.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Prayer Of The Refugee.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Pretty Fly (For A White Guy).mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Pull Up (feat. NAV).mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Pure Water (with Migos).mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Ransom.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] red sky.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Revolution Radio.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Saint Cecilia.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] SAY MY GRACE (feat. Travis Scott).mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Seven Nation Army.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Sex on Fire.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Shadow of the Season.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Shenanigans (feat. Yung Bans).mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Shotta Flow.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] SIRENS.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] SkeeYee.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] SLIDE FOR ME.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Smooth Criminal.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Something In The Way.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Spectrum.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Spin Again.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Still Breathing.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Suge.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Sum 2 Prove.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Swallow My Pride.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Sweet Child O' Mine.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] sweet sweet.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Swervin (feat. 6ix9ine).mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Take Me Out.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Texas Cyclone.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Texas.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] That Fiya.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] The Diary of Jane - Single Version.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] The Kill.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] The Middle.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] The Motion.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] The Motto.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] This Is a Call.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] TIL FURTHER NOTICE (feat. James Blake & 21 Savage).mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Times Like These.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] TOES (feat. Lil Baby & Moneybagg Yo).mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Topanga.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] TORE UP.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Turks (with Gunna & ft. Travis Scott).mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Ultimate.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Uncle M.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Universally Speaking.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Up In Arms.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] VALENTINO.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] VIBEZ.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Volcano Girls.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Wake Me up When September Ends.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Walk This Way.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Want You Bad.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Watch (feat. Lil Uzi Vert & Kanye West).mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Way Out (feat. Big Sean).mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Whatever She Wants.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] When I Come Around.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Where Ya At (feat. Drake).mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Woah.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] You (feat. Travis Scott).mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] Young Harleezy.mp3
# Loaded [SPOTIFY-DOWNLOADER.COM] YSL (feat. Playboi Carti).mp3
# Loaded _WORLD - Seventeen.mp3
# All MFCC data saved to C:\Users\Dev\Documents\SpotifAI_MFCC_Data\combined_mfcc_data.csv

# %%
'''
//to check for a specific song


import librosa
import os
import pandas as pd
import numpy as np

# Specify the path to the song you want to test 
audio_file = "C:\\Users\\Dev\\Documents\\SpotifAI Audio Files Dataset\\2 MINUS 1 (Bonus Track) - SEVENTEEN.mp3"  # replace with the specific song

# Define the output folder
output_folder = "C:\\Users\\Dev\\Documents\\SpotifAI_MFCC_Data"
os.makedirs(output_folder, exist_ok=True)

# Try loading and processing the specified audio file
try:
    # Load the audio file using librosa
    x, sr = librosa.load(audio_file)
    print(f"Loaded {audio_file}")
    
    # Calculate MFCCs
    mfccs = librosa.feature.mfcc(y=x, sr=sr, n_mfcc=13)
    mfccs_mean = np.mean(mfccs, axis=1)
    mfccs_std = np.std(mfccs, axis=1)

    # Create DataFrame for MFCC features
    mfccs_df = pd.DataFrame()
    for i in range(0, 13):
        mfccs_df[f'mfccs_mean_{i}'] = [mfccs_mean[i]]
        mfccs_df[f'mfccs_std_{i}'] = [mfccs_std[i]]

    # Print MFCC DataFrame
    print(f"\nMFCC data for {audio_file}:\n", mfccs_df)

    # Save the MFCC DataFrame to a CSV file
    mfccs_df.to_csv(f'{output_folder}\\{os.path.basename(audio_file)}_mfcc_data.csv', index=False)

except Exception as e:
    print(f"Error processing {audio_file}: {e}")
